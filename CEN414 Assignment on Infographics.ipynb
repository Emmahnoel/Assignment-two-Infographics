# %%
import numpy as np
import matplotlib.pyplot as plt


N = 37

LabourForcePopulation = {2023768, 1588278, 3599981, 3251915, 2122724, 1362014, 2777485, 2468890, 1936998, 3120370, 1528582, 2095235, 1770459, 2467332, 995947, 3123271, 1553870, 3504777, 4022761, 1799855, 1556976, 2463102, 1612476, 7478256, 1366207, 1917790, 3116782, 2502482, 2466519, 4032123, 2084700, 4601135, 1672920, 2207684, 1113650, 1427042, 1736235}

ind = np.arange(N)

width = 0.5

p = plt.bar(ind, LabourForcePopulation, width)

plt.ylabel("Labour Force Population")
plt.title("Labour Force Population Per State 2018")



plt.xticks(ind,{"ABIA","ADAMAWA","AKWA-IBOM","ANAMBRA","BAUCHI","BAYELSA","BENUE","BORNO","CROSS RIVER","DELTA","EBONYI","EDO","EKITI","ENUGU","GOMBE","IMO","JIGAWA","KADUNA","KANO","KATSINA","KEBBI","KOGI","KWARA","LAGOS","NASARAWA","NIGER","OGUN","ONDO","OSUN","OYO","PLATEAU","RIVERS","SOKOTO","TARABA","YOBE","ZAMFARA","FCT"}, rotation = 90)





plt.show()

# %%
N = 37

TotalEmployedperstate = {1384054, 1257232, 2242228, 2683682, 1624123, 918576, 2218230, 1693827, 1343611, 2329085, 1205684, 1569481, 1412960, 2006869, 727057, 2242920, 1141943, 2564296, 2765631, 1542018, 1243933, 1977449, 1271808, 6389904, 991996, 1517905, 2605505, 2146219, 2218203, 3615293, 1463885, 2927144, 1237218, 1788779, 791184, 1170525, 1312485}

ind = np.arange(N)

width = 0.5

p = plt.bar(ind, LabourForcePopulation, width)

plt.ylabel("TotalEmployed")
plt.title("Total Employed LFP per state")



plt.xticks(ind,{"ABIA","ADAMAWA","AKWA-IBOM","ANAMBRA","BAUCHI","BAYELSA","BENUE","BORNO","CROSS RIVER","DELTA","EBONYI","EDO","EKITI","ENUGU","GOMBE","IMO","JIGAWA","KADUNA","KANO","KATSINA","KEBBI","KOGI","KWARA","LAGOS","NASARAWA","NIGER","OGUN","ONDO","OSUN","OYO","PLATEAU","RIVERS","SOKOTO","TARABA","YOBE","ZAMFARA","FCT"}, rotation = 90)





plt.show()

# %%
N = 37




TotalUnemployedperstate = {971940, 724613, 2081274, 1140385, 1000323, 678171, 1253173, 1404754, 979106, 1350328, 624371, 911077, 605826, 896774, 504951, 1351432, 1004200, 2027080, 2233789, 968656, 576712, 1097474, 685529, 2012469, 705787, 916391, 849912, 792992, 609184, 995220, 1074269, 2674076, 880738, 617684, 656020, 584865, 702388}


ind = np.arange(N)

width = 0.5

p = plt.bar(ind, LabourForcePopulation, width)

plt.ylabel("TotalUnemployed")
plt.title("Total Uemployed LFP per state")



plt.xticks(ind,{"ABIA","ADAMAWA","AKWA-IBOM","ANAMBRA","BAUCHI","BAYELSA","BENUE","BORNO","CROSS RIVER","DELTA","EBONYI","EDO","EKITI","ENUGU","GOMBE","IMO","JIGAWA","KADUNA","KANO","KATSINA","KEBBI","KOGI","KWARA","LAGOS","NASARAWA","NIGER","OGUN","ONDO","OSUN","OYO","PLATEAU","RIVERS","SOKOTO","TARABA","YOBE","ZAMFARA","FCT"}, rotation = 90)





plt.show()
